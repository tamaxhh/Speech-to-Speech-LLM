# %%
# Mount Google Drive for storing models and data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.chdir("/content/drive/MyDrive/Speech-to-Speech-LLM")

# %%
# Install required libraries
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install transformers datasets
# !pip install librosa soundfile
# !pip install accelerate
# !pip install wandb
# !pip install audiomentations
# !pip install git+https://github.com/huggingface/transformers.git

# Import essential libraries
import torch
import torchaudio
import librosa
import numpy as np
import pandas as pd
from transformers import (
    Wav2Vec2Processor,
    Wav2Vec2ForCTC,
    SpeechT5Processor,
    SpeechT5ForSpeechToSpeech,
    SpeechT5HifiGan
)
from datasets import load_dataset, Audio
import matplotlib.pyplot as plt
import IPython.display as ipd
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Check GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.1/86.1 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.5/248.5 kB 17.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: soxr
#     Found existing installation: soxr 1.0.0
#     Uninstalling soxr-1.0.0:
#       Successfully uninstalled soxr-1.0.0
# ...
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-senanni5
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-senanni5
#   Resolved https://github.com/huggingface/transformers.git to commit a43b36cf802f00616800e0bd4d748679236123ee
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# Navigate to the directory where you initialized the wrong git repo
# For example, if it's in the current directory, you can skip this step or use:
# import os
# os.chdir('/content/drive/MyDrive/Speech-to-Speech-LLM') # Replace with the actual path

# Remove the .git directory
# !rm -rf .git
